# %%
import pandas as pd
import folium
from folium import Marker
from folium.plugins import MarkerCluster
import sqlalchemy as dbs
import pymysql








# df = pd.read_csv('subway.csv')
# df.head()

# map = folium.Map(location=[35.1795543, 129.0756416], tiles="OpenStreetMap", zoom_start=11)
# map

# cluster = MarkerCluster()
# for _, i in df.iterrows():
#     cluster.add_child(
#         Marker(location = [i['역위도'], i['역경도']],
#                popup = "<pre>" + "노선명: " + str(i['노선명']) + "<br>" + "역사명: " + str(i['역사명']) + "<br>" + "</pre>",)
#     ).add_to(map)
    
# map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cefe286afb83b1296e398fede8d75a9c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cefe286afb83b1296e398fede8d75a9c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cefe286afb83b1296e398fede8d75a9c = L.map(
#                 &quot;map_cefe286afb83b1296e398fede8d75a9c&quot;,
#                 {
#                     center: [35.1795543, 129.0756416],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23ca0c51c2174bebd3fdac92d6e5c956 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_23ca0c51c2174bebd3fdac92d6e5c956.addTo(map_cefe286afb83b1296e398fede8d75a9c);
#
#
#             var marker_cluster_6c7ce91ecf2d608f51613ea7220379c8 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_9c563381afea2b05156e5906fa214ae8 = L.marker(
#                 [35.237363, 129.171823],
#                 {}
#             ).addTo(marker_cluster_6c7ce91ecf2d608f51613ea7220379c8);
#
#
#         var popup_47486259c70ddfaf38e26eb8ca6d0b93 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ca744a74e2266ae1417fd880becdb6a7 = $(`&lt;div id=&quot;html_ca744a74e2266ae1417fd880becdb6a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt;노선명: 부산도시철도 4호선&lt;br&gt;역사명: 안평역&lt;br&gt;&lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_47486259c70ddfaf38e26eb8ca6d0b93.setContent(html_ca744a74e2266ae1417fd880becdb6a7);
#
#
#
#         marker_9c563381afea2b05156e5906fa214ae8.bindPopup(popup_47486259c70ddfaf38e26eb8ca6d0b93)
#         ;
#
#
#
#
#             var marker_16337d9648ed218ce0f243bd61eefb86 = L.marker(
#                 [35.237363, 129.171823],
#                 {}
#             ).addTo(marker_cluster_6c7ce91ecf2d608f51613ea7220379c8);
#
#
#         var popup_ec9b17beff94e03bc8f748d2600b3c30 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0e5ca40ff7750d3553bc16895180a0a2 = $(`&lt;div id=&quot;html_0e5ca40ff7750d3553bc16895180a0a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt;노선명: 부산도시철도 4호선&lt;br&gt;역사명: 안평역&lt;br&gt;&lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_ec9b17beff94e03bc8f748d2600b3c30.setContent(html_0e5ca40ff7750d3553bc16895180a0a2);
#
#
#
#         marker_16337d9648ed218ce0f243bd61eefb86.bindPopup(popup_ec9b17beff94e03bc8f748d2600b3c30)
#         ;
#
#
#
#
#             var marker_1b44a60fccc7ddd297e1a3e6efb124ba = L.marker(
#                 [35.237363, 129.171823],
#                 {}
#             ).addTo(marker_cluster_6c7ce91ecf2d608f51613ea7220379c8);
#
#
#         var popup_29e1ee1106b9d53e8dcf92efd48ceb1f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_333605e4d63675fde78dd817090d5733 = $(`&lt;div id=&quot;html_333605e4d63675fde78dd817090d5733&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt;노선명: 부산도시철도 4호선&lt;br&gt;역사명: 안평역&lt;br&gt;&lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_29e1ee1106b9d53e8dcf92efd48ceb1f.setContent(html_333605e4d63675fde78dd817090d5733);
#
#
#
#         marker_1b44a60fccc7ddd297e1a3e6efb124ba.bindPopup(popup_29e1ee1106b9d53e8dcf92efd48ceb1f)
#         ;
#
#
#
#
#             var marker_fe0bb3e220698bdca14ffbe76d37106b = L.marker(
#                 [35.237363, 129.171823],
#                 {}
#             ).addTo(marker_cluster_6c7ce91ecf2d608f51613ea7220379c8);
#
#
#         var popup_09c2675812e16a277472cc572198a461 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_26226f76386d4462329485922282c947 = $(`&lt;div id=&quot;html_26226f76386d4462329485922282c947&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt;노선명: 부산도시철도 4호선&lt;br&gt;역사명: 안평역&lt;br&gt;&lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_09c2675812e16a277472cc572198a461.setContent(html_26226f76386d4462329485922282c947);
#
#
#
#         marker_fe0bb3e220698bdca14ffbe76d37106b.bindPopup(popup_09c2675812e16a277472cc572198a461)
#         ;
#
#
#
#
#             var marker_e167e62b90d76315f4603be6ddeeb576 = L.marker(
#                 [35.237363, 129.171823],
#                 {}
#             )
